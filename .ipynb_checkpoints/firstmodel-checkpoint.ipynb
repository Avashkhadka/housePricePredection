# %%
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import numpy as np

# %%
df=pd.read_csv('Bengaluru_House_Data.csv')

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[200], line 2
#       1 df.describe()
# ----> 2 df.drop(['area_type', 'availability', 'society'], inplace=True)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6130 def drop(
#    6131     self,
#    6132     labels: IndexLabel | ListLike = None,
#    (...)   6139     errors: IgnoreRaise = "raise",
#    6140 ) -> DataFrame | None:
#    6141     """
#    6142     Drop specified labels from rows or columns.
#    6143
#    (...)   6286             weight  1.0     0.8
#    6287     """
# -> 6288     return super().drop(
#    6289         labels=labels,
#    6290         axis=axis,
#    6291         index=index,
#    6292         columns=columns,
#    6293         level=level,
# ...

# %%
data.head(10)
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
# 5  Super built-up  Area  Ready To Move                Whitefield      2 BHK
# 6  Super built-up  Area         18-May          Old Airport Road      4 BHK
# 7  Super built-up  Area  Ready To Move              Rajaji Nagar      4 BHK
# 8  Super built-up  Area  Ready To Move              Marathahalli      3 BHK
# 9            Plot  Area  Ready To Move              Gandhi Bazar  6 Bedroom
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  str
#  1   availability  13320 non-null  str
#  2   location      13319 non-null  str
#  3   size          13304 non-null  str
#  4   society       7818 non-null   str
#  5   total_sqft    13320 non-null  str
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), str(6)
# memory usage: 936.7 KB

# %%
sns.scatterplot(data=df,y='total_sqft',x='price',alpha=0.4)
# Out:
# <Axes: xlabel='price', ylabel='total_sqft'>

# %%
sns.jointplot(data=df,x='bath',y='price')

# %%
df.drop(['area_type', 'availability', 'society'])

df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[196], line 1
# ----> 1 df.drop(['area_type', 'availability', 'society'])
#       3 df
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6130 def drop(
#    6131     self,
#    6132     labels: IndexLabel | ListLike = None,
#    (...)   6139     errors: IgnoreRaise = "raise",
#    6140 ) -> DataFrame | None:
#    6141     """
#    6142     Drop specified labels from rows or columns.
#    6143
#    (...)   6286             weight  1.0     0.8
#    6287     """
# -> 6288     return super().drop(
#    6289         labels=labels,
#    6290         axis=axis,
#    6291         index=index,
#    6292         columns=columns,
#    6293         level=level,
#    6294         inplace=inplace,
# ...

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# society         0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# dtype: int64

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 5      Super built-up  Area  Ready To Move                Whitefield
# 11               Plot  Area  Ready To Move                Whitefield
# ...                     ...            ...                       ...
# 13313  Super built-up  Area  Ready To Move               Uttarahalli
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
sns.jointplot(x='size',y='price',data=df, alpha=0.5)

# %%
sns.pairplot(df,kind='scatter',plot_kws={'alpha':0.5})

# %%
df.location
# Out:
# 0        Electronic City Phase II
# 1                Chikka Tirupathi
# 3              Lingadheeranahalli
# 5                      Whitefield
# 11                     Whitefield
#                    ...
# 13313                 Uttarahalli
# 13314           Green Glen Layout
# 13315                  Whitefield
# 13317       Raja Rajeshwari Nagar
# 13318             Padmanabhanagar
# Name: location, Length: 7496, dtype: str

# %%
df.location=df.location.str.strip()

# %%
df.location
# Out:
# 0        Electronic City Phase II
# 1                Chikka Tirupathi
# 3              Lingadheeranahalli
# 5                      Whitefield
# 11                     Whitefield
#                    ...
# 13313                 Uttarahalli
# 13314           Green Glen Layout
# 13315                  Whitefield
# 13317       Raja Rajeshwari Nagar
# 13318             Padmanabhanagar
# Name: location, Length: 7496, dtype: str

# %%
location_stat=df['location'].value_counts()

# %%
location_stat
# Out:
# location
# Whitefield                    398
# Sarjapur  Road                310
# Electronic City               238
# Kanakpura Road                216
# Thanisandra                   215
#                              ...
# Church Street                   1
# Sarvobhogam Nagar               1
# Near International Airport      1
# Palace Road                     1
# Abshot Layout                   1
# Name: count, Length: 626, dtype: int64

# %%
LocationLessThanTen=location_stat[location_stat<20]
LocationLessThanTen
# Out:
# location
# Binny Pete                    19
# Gunjur                        19
# EPIP Zone                     19
# Kaggalipura                   19
# Kudlu                         19
#                               ..
# Church Street                  1
# Sarvobhogam Nagar              1
# Near International Airport     1
# Palace Road                    1
# Abshot Layout                  1
# Name: count, Length: 540, dtype: int64

# %%
df.location = df.location.apply(lambda x: 'other' if x in LocationLessThanTen else x )

# %%
df['location'].value_counts()
# Out:
# location
# other                 2263
# Whitefield             398
# Sarjapur  Road         310
# Electronic City        238
# Kanakpura Road         216
#                       ...
# 9th Phase JP Nagar      21
# Kambipura               21
# Hosakerehalli           21
# Ramamurthy Nagar        21
# Sonnenahalli            21
# Name: count, Length: 87, dtype: int64

# %%
df.head(100)
# Out:
#                 area_type   availability                  location       size  \
# 0    Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1              Plot  Area  Ready To Move                     other  4 Bedroom
# 3    Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 5    Super built-up  Area  Ready To Move                Whitefield      2 BHK
# 11             Plot  Area  Ready To Move                Whitefield  4 Bedroom
# ..                    ...            ...                       ...        ...
# 168        Built-up  Area  Ready To Move           Electronic City      2 BHK
# 169        Built-up  Area  Ready To Move                     other      3 BHK
# 171  Super built-up  Area  Ready To Move                  Attibele      1 BHK
# 172  Super built-up  Area         18-Apr           Electronic City      2 BHK
# 173  Super built-up  Area  Ready To Move           Electronic City      3 BHK
#
# ...

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move                     other
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 5      Super built-up  Area  Ready To Move                Whitefield
# 11               Plot  Area  Ready To Move                Whitefield
# ...                     ...            ...                       ...
# 13313  Super built-up  Area  Ready To Move               Uttarahalli
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun                     other
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.location.unique()
# Out:
# <StringArray>
# ['Electronic City Phase II',                    'other',
#        'Lingadheeranahalli',               'Whitefield',
#        '7th Phase JP Nagar',                 'Sarjapur',
#               'Mysore Road',            'Bisuvanahalli',
#     'Raja Rajeshwari Nagar',              'Thanisandra',
#           'Electronic City',         'Ramagondanahalli',
#                 'Yelahanka',                   'Hebbal',
#            'Kanakpura Road',             'Kundalahalli',
#            'Sarjapur  Road',             'Doddathoguru',
#               'Bhoganhalli',     'Lakshminarayana Pura',
#                'Begur Road',                  'Varthur',
#               'Hegde Nagar',             'Haralur Road',
#               'Hennur Road',             'Kasavanhalli',
#                   'Kengeri',             'Yeshwanthpur',
#                'Chandapura',             'Rajaji Nagar',
#               'Devanahalli',            'Akshaya Nagar',
# ...

# %%
df.location.value_counts()
# Out:
# location
# other                 2263
# Whitefield             398
# Sarjapur  Road         310
# Electronic City        238
# Kanakpura Road         216
#                       ...
# 9th Phase JP Nagar      21
# Kambipura               21
# Hosakerehalli           21
# Ramamurthy Nagar        21
# Sonnenahalli            21
# Name: count, Length: 87, dtype: int64

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move                     other
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 5      Super built-up  Area  Ready To Move                Whitefield
# 11               Plot  Area  Ready To Move                Whitefield
# ...                     ...            ...                       ...
# 13313  Super built-up  Area  Ready To Move               Uttarahalli
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun                     other
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...
